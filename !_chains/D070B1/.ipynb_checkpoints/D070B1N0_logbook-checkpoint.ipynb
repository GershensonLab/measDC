# %% [markdown]
# ## Experimental environment setup

# %% [markdown]
# ### Library preparation

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import time, os, io
from PIL import ImageGrab
from IPython.display import Image, display
import clipboard
from scipy import stats
from si_prefix import si_format
from tqdm import tqdm, tqdm_notebook

import pandas as pd
import numpy as np
from io import StringIO 
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
plt.close('all')

import sys 
sys.path.append('..')
from meas_util import *

import qcodes as qc
from qcodes import Station, load_by_run_spec, load_by_guid
from qcodes.instrument.base import Instrument
from qcodes.dataset.experiment_container import (Experiment,
                                                 load_last_experiment,
                                                 new_experiment)
from qcodes.dataset.database import initialise_database
from qcodes.dataset.measurements import Measurement
from qcodes.dataset.plotting import plot_by_id, get_data_by_id, plot_dataset
from qcodes.dataset.data_set import load_by_id
# from qcodes.dataset.data_export import get_shaped_data_by_runidb
# Out:
# C:\Users\KelvinOX25\Anaconda3\lib\site-packages\qcodes\dataset\database.py:13: UserWarning: The module `qcodes.dataset.database` is deprecated.
# Public features are available at the import of `qcodes`.
# Private features are available in `qcodes.dataset.sqlite.*` modules.
#   warnings.warn('The module `qcodes.dataset.database` is deprecated.\n'

# %%
from qcodes.instrument_drivers.Lakeshore.Model_372 import Model_372
from qcodes.instrument_drivers.tektronix.AWG3252_Isrc import AWG3252_Isrc
from qcodes.instrument_drivers.HP.HP34401 import HP34401
from qcodes.instrument_drivers.HP.HP34401_DL1201 import HP34401_DL1201
from qcodes.instrument_drivers.Keithley.Keithley_2600_channels import *
from qcodes.instrument_drivers.tektronix.AWG5204_Isrc import AWG5204_Isrc
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\KelvinOX25\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-3-b8fa7452c3fa>", line 6, in <module>
#     from qcodes.instrument_drivers.tektronix.AWG5204_Isrc import AWG5204_Isrc
#
#   File "C:\Users\KelvinOX25\Anaconda3\lib\site-packages\qcodes\instrument_drivers\tektronix\AWG5204_Isrc.py", line 36
#     set_cmd = getattr(self, f'ch{ch}').fgen_dclevel.set,
#     ^
# SyntaxError: keyword argument repeated

# %%
# #This code saves the image sources in clipboard into png file and copy a short PY code back into clipboard to display the specific png file. 

# import time, os
# dir_path = os.getcwd()
# pngpath = dir_path+"\\img\\{}{}{}-{}{}{}.png".format(time.localtime()[0]%100,time.localtime()[1],time.localtime()[2],time.localtime()[3],time.localtime()[4],time.localtime()[5])

# from PIL import ImageGrab
# img = ImageGrab.grabclipboard()
# img.save(pngpath, 'PNG')

# from IPython.display import Image, display
# display(Image(filename=pngpath))

# import clipboard
# clipboard.copy('display(Image(filename=r\'{}\'))'.format(pngpath))

# %%
# display(Image(filename=r'C:\Users\KelvinOX25\Documents\GitHub\measDC\55B1_revist 1D chain\img\191111-185418.png'))

# %% [markdown]
# ### Experiment scripts

# %% [markdown]
# ### Instrument nicknames and QC database initialization

# %%
try:
   Instrument.close_all()
except KeyError:
   pass    
except NameError:
   pass 

K2602 =  Keithley_2600(name = 'K2602', address = "GPIB::26::INSTR" )
Flux_chA = K2602.smua.curr
Flux_chB = K2602.smub.curr
Bfield =  Flux_chA

LS370 = Model_372(name = 'LS370 input Ch', address = 'GPIB::12::INSTR', terminator='\n')
T8 = LS370.ch08.temperature
htr = LS370.sample_heater

# Isrc = AWG5204_Isrc('gen', 'TCPIP0::AWG52000-XXXX::inst0::INSTR', ch = 1, R_bias = 1e9, Attn = 1)
#for 5204 we still need a code for init()
Isrc = AWG3252_Isrc('gen', 'TCPIP0::192.168.13.32::inst0::INSTR',  R_bias = 1e9, Attn = 1)
Isrc.init()

Vmeter = HP34401_DL1201('meter', 'GPIB0::8::INSTR', Gain = 100)
Vmeter.init('fast 6')

station = qc.Station(Isrc, Vmeter)
# Out:
# Connected to: Keithley Instruments Inc. 2602A (serial:1272049, firmware:2.1.5) in 0.50s
# Connected to: LSCI 370 (serial:370665, firmware:04102008) in 0.09s

# %%
SAMPLE = '70B1N7'
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format(SAMPLE)   
initialise_database()

# %% [markdown]
# ### Fridge handling log

# %%
# action = 'User: wsLu. Sample: {}. Roughing'.format(SAMPLE)
# action = 'ON Turbo @P1 = 6.47E-2'
# action = 'ON PT @P1 = 8.26E-4. ON HS-STILL, HS-MC'
# action = 'Test Cyro eff., t1hr @P1 = 3.51E-6'
# action = 'Add exchange gas thru v3'
# action = 'Pump coldtrap to P6 = 1.89E-1'
# action = 'Start Pulse_PreCool @T8 = 11.56K'
# action = 'Start Condense_wLN2'
# action = 'base T'
action = 'Warm up to RT'

# Tlst = [48, 3.7, 0.661, 0.030, 0.80]
Tlst = ['dont care']
flow = '0.00'
stillOut = '0'

tAbrStr = time.asctime()
actionStr = '\n\t'+action+'\n'
TPstr = '\tT[1,2,5,6,8]:\t{}\n'.format(Tlst)
misc = '\tFlow = {}, \tStill = {}%\n\n'.format(flow, stillOut)
clipboard.copy(tAbrStr+actionStr+TPstr+misc)

T8.get()
# Out:
# 0.0419358

# %% [markdown]
# Mon Nov 11 19:30:30 2019
# 	Warm up to RT
# 	T[1,2,5,6,8]:	['dont care']
# 	Flow = 0.00, 	Still = 0%
#
# Thu Nov  8 19:00:00 2019
#     warm up until T6 above 10K to collect all mixtures
#     cool back down at 23:00:00
#
# Mon Nov  4 01:28:46 2019
# 	base T
# 	T[1,2,5,6,8]:	[47, 3.7, 0.735, 0.0238, 0.0343]
# 	Flow = 0.58, 	Still = 15%
#
# Mon Nov  4 01:28:46 2019
# 	base T
# 	T[1,2,5,6,8]:	[48, 3.7, 0.661, 0.0257, 0.0352]
# 	Flow = 0.43, 	Still = 10%
#
# Mon Nov  4 00:39:03 2019
# 	Change Still to 10%, flow became 0.45
# 	T[1,2,5,6,8]:	[48, 3.7, 0.479, 0.75, 0.75]
# 	Flow = 0.20, 	Still = 0%
#
# Sun Nov  3 22:20:04 2019
# 	Start Condense_wLN2
# 	T[1,2,5,6,8]:	[49.6, 4.2, 5.1, 6.6, 7.75]
# 	Flow = 0.00, 	Still = 0%
#
# Sun Nov  3 19:36:08 2019
# 	Start Pulse_PreCool @T8 = 11.56K
# 	T[1,2,5,6,8]:	[48, 4.6, 6.2, 8.6, 11.5]
# 	Flow = 0.00, 	Still = 0%
#
# Sun Nov  3 19:22:33 2019
# 	Pump coldtrap to P6 = 1.89E-1
# 	T[1,2,5,6,8]:	[48, 4.6, 6.2, 8.6, 28]
# 	Flow = 0.00, 	Still = 0%
#
# Sun Nov  3 16:20:00 2019
# 	T[1,2,5,6,8]:	[50, 7.4, 13, 18, 28]
# 	Flow = 0.00, 	Still = 0%
#
# Sun Nov  3 12:34:05 2019
# 	Pump coldtrap to P6 = 1.89E-1
# 	T[1,2,5,6,8]:	[52, 11, 23, 31, 54]
# 	Flow = 0.00, 	Still = 0%
#
# Sun Nov  3 09:13:20 2019
# 	Test Cyro eff., t1hr @P1 = 3.51E-6
# 	T[1,2,5,6,8]:	[60, 15, 37, 40, 102]
# 	Flow = 0.00, 	Still = 0%
#
# Sun Nov  3 08:00:15 2019
# 	Add exchange gas thru v3
# 	T[1,2,5,6,8]:	[60, 15, 37, 40, 102]
# 	Flow = 0.00, 	Still = 0%
#
# Sat Nov  2 18:57:35 2019
# 	ON PT @P1 = 8.26E-4. ON HS-STILL, HS-MC
# 	T[1,2,5,6,8]:	['dont care']
# 	Flow = 0.00, 	Still = 0%
#
# Sat Nov  2 16:38:01 2019
# 	ON Turbo @P1 = 6.47E-2
# 	T[1,2,5,6,8]:	['dont care']
# 	Flow = 0.00, 	Still = 0%
#
# Sat Nov  2 12:30:00 2019
# 	User: wsLu. Sample: Q1D070B1. Roughing
# 	T[1,2,5,6,8]:	['dont care']
# 	Flow = 0.00, 	Still = 0%

# %% [markdown]
# ### Measurement scripts

# %%
def setup():
    Isrc.I.set(0)

def cleanup():
    Isrc.I.set(0) 
    Bfield.set(0)

# %%
def IVC_udu (amp, stp, Gain, R_bias, Attn, tfsstb = 0.025):
    
    meas = set_meas(Vmeter.V, Isrc.I, setup = setup, cleanup = cleanup)

    Vmeter.set_Gain ( Gain )
#     Isrc.set_R_Attn ( R_bias, Attn )
    
    i_list = udu_list(amp, stp)
    ti_list = tqdm_notebook(i_list)

    name_exp(sample = SAMPLE, exp_type = 'tst IVC 5204 line @T={}K, B={}A'.format(si_format(T8.get()), si_format(Bfield.get(), precision = 3)))
    with meas.run() as datasaver:
        for i in ti_list:
            
            Isrc.I.set(i)
            time.sleep(tfsstb)
            V = Vmeter.V.get()

#             Vs.append(V)
            res = [( Isrc.I, i ), ( Vmeter.V, V )]
            datasaver.add_result(*res) 
        dataid = datasaver.run_id 

#     plot_by_id(dataid, marker = 'o', ls = '')

# %%
def Bperiod_meas (amp=1e-9, Gain=100, R_bias=1e9, Attn=1, B_list = [0]):

    meas = set_meas(Vmeter.V, Bfield, setup = setup, cleanup = cleanup)
    Vmeter.set_Gain (Gain = Gain) 
    Isrc.set_R_Attn (R_bias = R_bias, Attn=Attn)

    tB_list = tqdm_notebook(B_list)

    name_exp(sample = SAMPLE, exp_type = 'B periodicity @T={}K, Ib={}A'.format(si_format(T8.get()), si_format(amp, precision=0)))
    with meas.run() as datasaver:

        Isrc.I.set(amp)
        for B in tB_list:

            Bfield.set(B)
            time.sleep(0.5)
            V = Vmeter.V.get()
            volt = [( Bfield, B ), ( Vmeter.V, V )]

            datasaver.add_result(*volt) 

    Isrc.I.set(0)
    Bfield.set(0)
    return datasaver.run_id

# %%
def Ic_meas (amp, stp, thr, Gain, R_bias, Attn, tfsstb = 0.025):

    meas = set_meas(Vmeter.V, Isrc.I, setup = setup, cleanup = cleanup)
    Vmeter.set_Gain (Gain) 
    Isrc.set_R_Attn (R_bias, Attn)
    
    i_list_u = np.linspace(0,  amp,  round (amp/stp) + 1)
    ti_list_u = tqdm_notebook(i_list_u)
    i_list_d = np.linspace(0, -amp,  round (amp/stp) + 1)    
    ti_list_d = tqdm_notebook(i_list_d)
    ti_lists = [ ti_list_u ,  ti_list_d]

#     Vs = []
#     Is = []
    
    name_exp(sample = SAMPLE, exp_type = 'sc branch @T={}K, B={}A'.format(si_format(T8.get()), si_format(B, precision = 3)))
    with meas.run() as datasaver:
        for ti_list in ti_lists:
            
            Isrc.I.set(0)
            V_ = Vmeter.V.get()            
            time.sleep(1)
            
            for i in ti_list:
            
                Isrc.I.set(i)
                time.sleep(tfsstb)

                V = Vmeter.V.get()
                dV = V - V_
                V_ = V 
#                 print(dV)
                
                if (abs(dV) > thr)  or (abs(V) > 4e-3 ) : #
                    break

#                 Is.append(i)
#                 Vs.append(V)
                res = [( Isrc.I, i ), ( Vmeter.V, V )]
                datasaver.add_result(*res) 
            dataid = datasaver.run_id 
#         plot_by_id(dataid, marker = 'o', ls = '')        
#         print(extract_Isw_R0_by_id (dataid))

# %%
def IVcB_meas (i_list, B_list, thr=1e-3, Gain=100, R_bias=1e9, Attn=1, tfsstb = 0.025):

    Vmeter.set_Gain (Gain = Gain) 
    Isrc.set_R_Attn (R_bias = R_bias, Attn=Attn)

#     amp=1e-9
#     Istp=2e-12
#     stp = Istp
#     i_list_u = np.linspace(0,  amp,  round (amp/stp) + 1)
#     i_list_d = np.linspace(0, -amp,  round (amp/stp) + 1)
#     i_lists = [i_list_u ,  i_list_d]
#     i_lists = udu_list(amp, Istp) for udu meas

#     ti_list_u = tqdm_notebook(i_list_u, leave = False)
#     ti_list_d = tqdm_notebook(i_list_d, leave = False)
    
    i_lists = [i_list]
    
#     B_list = B_list
#     B_list = np.linspace(0,  Bset,  round (Bset/Bstp) + 1)
#     B_list = [0.260E-3, 1.600E-3]

    meas = set_meas(Vmeter.V, Isrc.I,setup = setup, cleanup = cleanup)
    tB_list = tqdm_notebook(B_list)
    for B in tB_list:

        name_exp(sample = SAMPLE, exp_type = 'full IVc(B) @T={}K, B={}A'.format(si_format(T8.get()), si_format(B, precision =3)))
        with meas.run() as datasaver:

            Bfield.set(B)
    #         Is, Vs = [], []
            for i_list in i_lists:

                Isrc.I.set(0)
                V_ = Vmeter.V.get()
                time.sleep(1)

                for i in i_list:

                    Isrc.I.set(i)
                    time.sleep(tfsstb)

                    V = Vmeter.V.get()
                    dV = V - V_
                    V_ = V

                    if  (abs(V) > 6.4e-3) : #(abs(dV) > thr)  or
#                         counter +=
#                         if counter >= 10
                            break
#                         else
                            

                    res = [( Isrc.I, i ), ( Vmeter.V, V )]
                    datasaver.add_result(*res) 

    #                 Is.append(i)
    #                 Vs.append(V)
    #         Is, Vs = np.array(Is), np.array(Vs) 
    #         print(extract_Isw_R0 (Is, Vs))

    return datasaver.run_id 


#             plot_by_id(dataid)

# %%
# adaptive step size with while loop
def IVcB_ada(npts_B = 51, tfsstb = 0.025):
    ZF =  0.004e-3
    FF =  0.224e-3
    dF =  0.250e-3
    midF = 0.154e-3

    maxI = 3e-9
    step_ff = 2e-12
    step_f = 10e-12
    step_c = 200e-12

    thr = 3e-3

    B_list = np.linspace(ZF, ZF + 1.0*dF, npts_B)
    tB_list = tqdm_notebook(B_list)

    Vmeter.set_Gain (Gain = 100) 
    Isrc.set_R_Attn (R_bias = 1e9, Attn=1)

    for B in tB_list:
        meas = set_meas(Vmeter.V, Isrc.I, setup = setup, cleanup = cleanup)

        name_exp(sample = SAMPLE, exp_type = 'Bscan IVC @T ={:2.1f}mK, B = {}A'.format(T8.get()/1e-3, si_format(B)) )  
        with meas.run() as datasaver:

                Bfield.set(B)

                for pm in [1, -1]:

                    i = 22.5e-12

                    Isrc.I.set(i)
                    time.sleep(1)
                    V_off = Vmeter.V.get()
                    V_ = V_off
                    time.sleep(1)

                    if B < midF:
                        step = step_f
                    else:
                        step = step_ff

                    while abs(i) < maxI:

                        Isrc.I.set(i)
                        time.sleep(tfsstb)

                        V = Vmeter.V.get()
                        dV = V - V_
                        V_ = V

                        res = [( Isrc.I, i - 22.5e-12 ), ( Vmeter.V, V  )]

                        datasaver.add_result(*res) 

                        if (abs(dV) > thr)  or (abs(V - V_off) > 4e-3 ) : #
                            step = step_c

                        i += pm*step

    #     dataid = datasaver.run_id 
    #     plot_by_id(dataid)

# %%
def RTc (dataPts = 100, Gain = 100, R_bias = 1e9, Attn = 1, tfsstb = 0.1, I_bias = 0.4e-9, T_str = 0):
    
    meas = set_meas(Vmeter.V, Isrc.I, setup = setup, cleanup = cleanup)

    Vmeter.set_Gain ( Gain )
    Isrc.set_R_Attn ( R_bias, Attn )
    pts_list = np.arange(1, dataPts)
    tpts_list = tqdm_notebook(pts_list)

    name_exp(sample = SAMPLE, exp_type = 'RTc')
    with meas.run() as datasaver:
        for j in tpts_list:

            Ib_list = udu_list(1*I_bias, 0.5*I_bias)
            V1_list = []
            T8_lst = []
            for Ib in Ib_list:
                Isrc.I.set(Ib)
                time.sleep(tfsstb)
                V1_list = np.append(V1_list, Vmeter.V.get())
                T8_lst.append(T8.get())
            T_now = sum(T8_lst)/len(T8_lst)
            R_now, intercept, r_value, p_value, std_err = stats.linregress(Ib_list, V1_list)
            
            res = [( Isrc.I, T_now ), ( Vmeter.V, R_now )]
            with open('CH0 T {}.log'.format(time.strftime('%d-%m-%y', time.localtime())),'a+') as fp:
                fp.write(time.strftime(' %d-%m-%y,%H:%M:%S,{}'.format(R_now), time.localtime())+'\n')
                fp.close
            with open('CH8 T {}.log'.format(time.strftime('%d-%m-%y', time.localtime())),'a+') as fp:
                fp.write(time.strftime(' %d-%m-%y,%H:%M:%S,{}'.format(T_now), time.localtime())+'\n')
                fp.close

#             print('Current T8= {}K'.format(si_format(T8.get()), end='\r'))
            sys.stdout.write("\rCurrent T8= {}K".format(si_format(T8.get())))
            sys.stdout.flush()
            datasaver.add_result(*res)
            if T_str == 300:
                time.sleep(54.5)
            else:
                time.sleep(0.05)

    cleanup()
    return datasaver.run_id

# %%
def uduFF_list(amp1=240e-12, amp2=2000e-12, stp1=2e-12, stp2=80e-12):

    i_list_uf = np.linspace(0, amp1, round (amp1/stp1) + 1)
    i_list_uc = np.linspace(amp1, amp2, round ((amp2-amp1)/stp2) + 1)
    i_list = np.append(i_list_uf, i_list_uc)

    i_list_d = [np.linspace(amp2, amp1, round ((amp2-amp1)/stp2) + 1),
                np.linspace(amp1, 0, round (amp1/stp1) + 1),
                np.linspace(0, -1*amp1, round (amp1/stp1) + 1),
                np.linspace(-1*amp1, -1*amp2, round ((amp2-amp1)/stp2) + 1)]
    for lst in i_list_d:
        i_list = np.append(i_list, lst)

    i_list_ucn = np.linspace(-1*amp2, -1*amp1, round ((amp2-amp1)/stp2) + 1)
    i_list_ufn = np.linspace(-1*amp1, 0, round (amp1/stp1) + 1)
    i_list = np.append(i_list, i_list_ucn)
    i_list = np.append(i_list, i_list_ufn)

    return i_list

# %% [markdown]
# ### Biasing scheme

# %%
display(Image(filename=r'C:\Users\KelvinOX25\Documents\GitHub\DC meas\img\191026-183349.png'))

# %% [markdown]
# ## Data acqusition

# %% [markdown]
# ### Device detail
#
# - ID: Q1D070B1 (aka "001" on the chip corner)
# - Pre-experiment electrical performance
#  - N3: (2ba,1ba), $R_{RT, 4pb} = 165k\Omega$ This device was connected w/ **$200k\Omega$ by-passed**.
#  - N5: (8ab,12ba), $R_{RT, 4pb} = 226k\Omega$, General check for $30k\Omega/JJ$
#  - N7: (3ba,4ba), $R_{RT, 4pb} = 83k\Omega$, **This device is for P(E) theory**
#  - N0: (6ab,7ab), $R_{RT, 4pb} = 160k\Omega$, To compare w/ N3
#
#
#  - $R_{G, 2pb}$ = OVFL on all devices
#  - $R_{coil} = 1.24k\Omega$
#  - $R_{therm} = 1.056k\Omega$
#
#
# - Device scheme
#  - Type: 1D chain with 16 SQUIDs, pentagon capacitors with larger spacing to accomodate larger junction area design.
#  - Shunting capacitor C0: No Pt yet.
#  - C0 area:
#  - SQUID area:
#  - Junction area:
#  - Oxidation: 169 torr, 10+4min (by Plamen) (A 20x, ox 140x, w>>2.5um x 2.5um)

# %% [markdown]
# ### Device quick overview

# %% [markdown]
# N3 **(low Z_env)**
# RN=165E3/8, JJwidthUM=sqrt(0.2205*.17325), metalTHK=250E-10, Tc=1.34
# [RN_JJ (kohm), Rs_JJ (kohm-um^2)] = [20.625, 0.98947]
# [I_AB (nA), EJ (mK)] = [15.51322, 369.78959]
# [C_JJQP (fF), EC (mK)] = [1.91008, 486.6938]
# [C0 (fF), EC0 (mK)] = [463.10944, 2.00735]
# [Freq_plasma (GHz))] = [1.60569]
# [Q, Beta, EJ/EC] = [96.4, 9286.2, 184.2]
#
# RRR(RT/10K) = 0.874

# %%
display(Image(filename=r'\\JOSH-PC\OurData_OneDrive\img\70B1\N3.jpg'))

# %%
# N3
# qckplt(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191102-70N3_IV300K-124250.txt')

# %%
# qckplt(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191103-70N3_IV10K-194751.txt')

# %%
# N3, preamp with bat power
qckplt0(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N3_IVc-115218.txt', fitArr = [0,10])
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# N5 **(30kohm/JJ)**
# RN=226E3/8, JJwidthUM=sqrt(0.19175*.1525), metalTHK=250E-10, Tc=1.34
# [RN_JJ (kohm), Rs_JJ (kohm-um^2)] = [28.25, 1.06762]
# [I_AB (nA), EJ (mK)] = [11.32603, 269.97912]
# [C_JJQP (fF), EC (mK)] = [1.46209, 635.81743]
# [C0 (fF), EC0 (mK)] = [463.10944, 2.00735]
# [Freq_plasma (GHz))] = [1.37198]
# [Q, Beta, EJ/EC] = [112.8, 12719.3, 134.5]
#
# RRR(RT/10K) = 0.847

# %%
display(Image(filename=r'\\JOSH-PC\OurData_OneDrive\img\70B1\N5.jpg'))

# %%
# N5
# qckplt(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191102-70N5_IV300K-124546.txt')

# %%
# qckplt(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191103-70N5_IV10K-194541.txt')

# %%
# line power
# qckplt0(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N5_IVc-101229.txt',fitArr = [0,10])

# %%
# bat power
qckplt0(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N5_IVc-125150.txt',fitArr = [11,20])
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %% [markdown]
# N7 **(P(E) theory)**
# RN=83E3/8, JJwidthUM=sqrt(0.62*.151), metalTHK=250E-10, Tc=1.34
# [RN_JJ (kohm), Rs_JJ (kohm-um^2)] = [10.375, 1.13003]
# [I_AB (nA), EJ (mK)] = [30.83954, 735.12388]
# [C_JJQP (fF), EC (mK)] = [4.681, 198.59532]
# [C0 (fF), EC0 (mK)] = [463.10944, 2.00735]
# [Freq_plasma (GHz))] = [2.26394]
# [Q, Beta, EJ/EC] = [68.3, 4671.2, 366.2]]
#
# RRR(RT/10K) = 0.869

# %%
display(Image(filename=r'\\JOSH-PC\OurData_OneDrive\img\70B1\N7.jpg'))

# %%
# N7
# qckplt(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191102-70N7_IV300K-124847.txt')

# %%
# qckplt(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191103-70N7_IV10K-194308.txt')

# %%
qckplt0(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N7_IVc-133848.txt', fitArr = [0,10])
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %% [markdown]
# N0 **(high Z_env)**
# RN=160e3/8, JJwidthUM=sqrt(0.2325*.19875), metalTHK=250E-10, Tc=1.34
# [RN_JJ (kohm), Rs_JJ (kohm-um^2)] = [20.0, 1.13915]
# [I_AB (nA), EJ (mK)] = [15.99801, 381.34551]
# [C_JJQP (fF), EC (mK)] = [2.31047, 402.35329]
# [C0 (fF), EC0 (mK)] = [463.10944, 2.00735]
# [Freq_plasma (GHz))] = [1.63058]
# [Q, Beta, EJ/EC] = [94.9, 9004.8, 190.0]
#
# RRR(RT/10K) = 0.950

# %%
display(Image(filename=r'\\JOSH-PC\OurData_OneDrive\img\70B1\N0.jpg'))

# %%
# N0
# qckplt(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191102-70N0_IV300K-125216.txt')

# %%
# qckplt(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191103-70N0_IV10K-195610.txt')

# %%
# preamp with bat power
qckplt0(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N0_IVc-121229.txt')
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %% [markdown]
# ## Scripts

# %% [markdown]
# ### Measurement runs

# %% [markdown]
# ### Data processing scripts

# %%
def extract_Isw_R0 (Is,Vs):

    Isw = (np.max(Is) - np.min(Is) ) /2

    order = Is.argsort()        
    Is, Vs = Is[order], Vs[order]
    n = len(Is)
    n_min, n_max = np.int(n/3), np.int(2*n/3)        
#         print(n_min, n_max)
    n_sl = slice(n_min, n_max)

    R0 = np.mean(np.diff(Vs[n_sl])) / np.mean(np.diff(Is[n_sl]))        
    return Isw, R0

# %%
def extract_Isw_R0_by_id (idx):
    
    alldata = get_data_by_id(idx)
    
    Is = alldata[0][0]['data']
    Vs = alldata[0][1]['data']
        
    return extract_Isw_R0 (Is,Vs)

# %%
def databyid (run_id: int, **kwargs):
    from qcodes.dataset.data_set import load_by_id

    dataset = load_by_id(run_id)
    title = f"#{run_id}, Exp {dataset.exp_name} ({dataset.sample_name})"
    alldata = get_data_by_id(run_id)
    
    return ({'title':title, 'alldata':alldata})

# %%
def dataread (filename, splitkw = '!DATASTR!'):
    with open(filename,'r') as file:
        rawtxt = file.read()
        splittxt = rawtxt.split(splitkw)    
    return(splittxt)

def filetoDFM (filename):
    datatxt = dataread(filename = filename)
    datastr = io.StringIO(datatxt[1])
    DataFM = pd.read_csv(datastr, sep = '\t')
    DataFM = DataFM.drop(DataFM.index[0])
    DataFM = DataFM.astype(float)
    return(DataFM, datatxt[0])

######################################################################

def pltMaxMin(lst, pMF = 1.1):
    pMin = lst.mean()-pMF*(lst.max()-lst.min())/2
    pMax = lst.mean()+pMF*(lst.max()-lst.min())/2
    pPos = (lst.mean()-lst.min())*pMF+lst.min()
    return(pMin,pMax,pPos)

######################################################################

def qcksubplt(ax, dataFM, param_dict, x_label, y_label):
    out = ax.plot(dataFM[x_label], dataFM[y_label], **param_dict)

    ax.set_ylim(pltMaxMin(dataFM[y_label])[0], pltMaxMin(dataFM[y_label])[1])
    ax.set_xlim(pltMaxMin(dataFM[x_label])[0], pltMaxMin(dataFM[x_label])[1])
    ax.set_title('{} ({})'.format(y_label, x_label), size ='large')
    ax.set_ylabel(y_label, fontsize='medium')
    ax.set_xlabel(x_label, fontsize='medium')  

    ax.ticklabel_format(axis='both', style='sci', scilimits=(0, 4))
    ax.tick_params(axis='both', labelsize='medium')    
    ax.minorticks_on()
    ax.grid(which='major', linestyle='-', linewidth='0.5', color='grey')
    ax.grid(which='minor', linestyle=':', linewidth='0.5', color='grey')
    ax.axhline(y=0, color='k')
    ax.axvline(x=0, color='k')
    return out

######################################################################

def qckplt (fname, showheader = False):
    data = filetoDFM(filename = fname)[0]
    
    plt.close('all')
    plt.rc('font', size=14)
    
    fig, ax_lst = plt.subplots(1, 2, figsize=(9, 4))

    qcksubplt(ax_lst[0], data, {'marker':'.','color':'r'}, 'IS', 'V1')
    ax_lst[0].text(pltMaxMin(data['IS'],pMF=0)[2], pltMaxMin(data['V1'],pMF=1.8)[2], '$T8 = {}K, \Delta T = {}K$'.format(si_format(data['T8'].mean(), precision =2),si_format(data['T8'].max()-data['T8'].min(), precision =2)), fontsize=12)
    slopeP, interceptP, r_valueP, p_valueP, std_errP = stats.linregress(data['IS'][int(np.floor(data['IS'].size*3/16)):int(np.floor(data['IS'].size*5/16))],data['V1'][int(np.floor(data['V1'].size*3/16)):int(np.floor(data['V1'].size*5/16))])
    slopeN, interceptN, r_valueN, p_valueN, std_errN = stats.linregress(data['IS'][int(np.floor(data['IS'].size*11/16)):int(np.floor(data['IS'].size*13/16))],data['V1'][int(np.floor(data['V1'].size*11/16)):int(np.floor(data['V1'].size*13/16))])
    ax_lst[0].text(pltMaxMin(data['IS'],pMF=0)[2], pltMaxMin(data['V1'],pMF=1.6)[2], '$R_{} = {}\Omega/{}\Omega$'.format('{+/-}',si_format(slopeP, precision =2),si_format(slopeN, precision =2)), fontsize=12)
#     slopeA, interceptA, r_valueA, p_valueA, std_errA = stats.linregress(data['IS'],data['V1'])
#     ax_lst[0].text(pltMaxMin(data['IS'],pMF=0)[2], pltMaxMin(data['V1'],pMF=1.4)[2], '$R = {}\Omega$'.format(si_format(slopeA, precision =2)), fontsize=12)
    
    qcksubplt(ax_lst[1], data, {'marker':'.','color':'b'}, 'Time', 'IS')
    
    fig.tight_layout()
    fig.suptitle('file {}'.format(fname.split(r'DC')[1]), x = 0.8, y = 0.02, size = 'x-small')
    fig.subplots_adjust(top=0.8)
    
    plt.show()
    
    if showheader:
        print(filetoDFM(filename = fname)[1])

def qckplt0 (fname, showheader = False, fitArr = [0,4]):
    data = filetoDFM(filename = fname)[0]
    
    plt.close('all')
    plt.rc('font', size=14)
    
    fig, ax_lst = plt.subplots(1, 2, figsize=(9, 4))

    qcksubplt(ax_lst[0], data, {'marker':'.','color':'r'}, 'IS', 'V1')
    ax_lst[0].text(pltMaxMin(data['IS'],pMF=0)[2], pltMaxMin(data['V1'],pMF=1.8)[2], '$T8 = {}K, \Delta T = {}K$'.format(si_format(data['T8'].mean(), precision =2),si_format(data['T8'].max()-data['T8'].min(), precision =2)), fontsize=12)
#     slopeP, interceptP, r_valueP, p_valueP, std_errP = stats.linregress(data['IS'][int(np.floor(0)):int(np.floor(4))],data['V1'][int(np.floor(0)):int(np.floor(4))])
#     slopeN, interceptN, r_valueN, p_valueN, std_errN = stats.linregress(data['IS'][int(np.floor(data['IS'].size-4)):int(np.floor(data['IS'].size))],data['V1'][int(np.floor(data['V1'].size-4)):int(np.floor(data['V1'].size))])
#     ax_lst[0].text(pltMaxMin(data['IS'],pMF=0)[2], pltMaxMin(data['V1'],pMF=1.6)[2], '$R_{} = {}\Omega/{}\Omega$'.format('{+/-}',si_format(slopeP, precision =2),si_format(slopeN, precision =2)), fontsize=12)
    slopeA, interceptA, r_valueA, p_valueA, std_errA = stats.linregress(data['IS'][fitArr[0]:fitArr[1]],data['V1'][fitArr[0]:fitArr[1]])
    ax_lst[0].text(pltMaxMin(data['IS'],pMF=0)[2], pltMaxMin(data['V1'],pMF=1.6)[2], '$R_0 = {}\Omega$'.format(si_format(slopeA, precision =2)), fontsize=12)
    
    qcksubplt(ax_lst[1], data, {'marker':'.','color':'b'}, 'Time', 'IS')
    
    fig.tight_layout()
    fig.suptitle('file {}'.format(fname.split(r'DC')[1]), x = 0.8, y = 0.02, size = 'x-small')
    fig.subplots_adjust(top=0.8)
    
    plt.show()
    
    if showheader:
        print(filetoDFM(filename = fname)[1])

######################################################################

def qlot_by_id(plotID):
    data = databyid(plotID)
    
    DTF = {data['alldata'][0][0]['name'] : pd.Series(data['alldata'][0][0]['data'], index = np.arange(len(data['alldata'][0][0]['data']))), 
           data['alldata'][0][1]['name'] : pd.Series(data['alldata'][0][1]['data'], index = np.arange(len(data['alldata'][0][0]['data'])))} 
    DTF = pd.DataFrame(DTF)

    plt.close('all')
    plt.rc('font', size=8)
    fig, ax_lst = plt.subplots(1, 2, figsize=(6, 4))
    DTF.plot(ax=ax_lst[0], kind='scatter', x='gen_I', y='meter_V', grid=True)
    DTF.plot(ax=ax_lst[1], y='gen_I', grid=True)

    ax_lst[0].set_xlim(pltMaxMin(DTF['gen_I'])[0:2])
    ax_lst[0].set_ylim(pltMaxMin(DTF['meter_V'])[0:2])
    ax_lst[0].ticklabel_format(axis='both', style='sci', scilimits=(0, 4))
    ax_lst[1].ticklabel_format(axis='both', style='sci', scilimits=(0, 4))

    slopeP, interceptP, r_valueP, p_valueP, std_errP = stats.linregress(DTF['gen_I'][int(np.floor(DTF['gen_I'].size*3/16)):int(np.floor(DTF['gen_I'].size*5/16))],DTF['meter_V'][int(np.floor(DTF['meter_V'].size*3/16)):int(np.floor(DTF['meter_V'].size*5/16))])
    slopeN, interceptN, r_valueN, p_valueN, std_errN = stats.linregress(DTF['gen_I'][int(np.floor(DTF['gen_I'].size*11/16)):int(np.floor(DTF['gen_I'].size*13/16))],DTF['meter_V'][int(np.floor(DTF['meter_V'].size*11/16)):int(np.floor(DTF['meter_V'].size*13/16))])
    ax_lst[0].text(pltMaxMin(DTF['gen_I'],pMF=0)[2], pltMaxMin(DTF['meter_V'],pMF=1.6)[2], '$R_{} = {}\Omega/{}\Omega$'.format('{+/-}',si_format(slopeP, precision =2),si_format(slopeN, precision =2)))

    plt.show()

# %% [markdown]
# ### Measurement plans

# %%
dF = 0.250e-3
midF = 0.154e-3


keys  = ['ids',                  'T',          'B',                                          'Vthr']
valss = [[range(105, 205+1)[:],   45e-3,       np.linspace(ZF, ZF + 1.1*dF, 101)[:],         4e-3],
         [range(208, 292+1)[:],   50e-3,       np.linspace(ZF, ZF + 1.1*dF, 101)[:-16],      4e-3]
         [range(296, 346+1)[:],   70e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
         [range(347, 397+1)[:],   90e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
         [range(398, 448+1)[:],  110e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
         [range(450, 500+1)[:],  110e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(501, 551+1)[:],  130e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(552, 602+1)[:],  150e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(603, 653+1)[:],  170e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(654, 704+1)[:],  190e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(705, 755+1)[:],  210e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(758, 808+1)[:],  230e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],

         [range(988, 1038+1)[:], 290e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(1039, 1089+1)[:],310e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         

        ]  
        

ZF =  0.004e-3
FF =  0.224e-3
    
exps = [{ key : val for key, val in zip(keys, vals)  }  for vals in valss ]

# %% [markdown]
# >>>>>>>> ## Plan to be done

# %% [markdown]
# **Plan**
#
# Until we find recovery of $I_{SW}$, at each T perform:
# - Full IVcB(thr = 8mV) for np.linspace(1e-3, 2e-3, 6)
# - IVcB(thr = 4mV) for np.linspace(1e-3, 2e-3, 51)
#
# After we find recovery of $I_{SW}$, at each T perform:
# - ZF, FF for Full IVcB(thr = 8mV) [0.260E-3, 1.600E-3, 2.940E-3]
#
# **Selected meas to be done**
# - Check Field stability B_list = [0.260E-3, 1.600E-3, 2.940E-3]...
# - Check Periodicity B_list = [0.260E-3, 1.600E-3, 2.940E-3]
# - Check AWG5204 ramping features, noise level as a source (judging from $I_{SW}$)
# - Check Attn. effects as reducing noise level from the source.

# %%
SAMPLE = '70B1N0'
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format(SAMPLE)   
initialise_database()

f,ax=plt.subplots()
for i in [30,31,32,33]:
    data = get_data_by_id(i)
    Is = data[0][0]['data']
#     Is = Is - 22.5e-12
    Vs = data[0][1]['data']
    ax.plot(Is, Vs, '.', ls='-')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# **. Need to trace back I_SW branch to see if gain drifts (IV_meas)
# **. Measure 10 curves up to $I_{SW}$

# %% [markdown]
# ### Results Summary

# %% [markdown]
# ### Instrumentations

# %%
# Field periodicity
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format('70B1N7')
initialise_database()

f,ax=plt.subplots()
for i in [12]:
    data = get_data_by_id(i)
    Is = data[0][0]['data']
#     Is = Is - 22.5e-12
    Vs = data[0][1]['data']
    ax.plot(Is, Vs, '.', ls='-')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# T8 and heater range

display(Image(filename=r'C:\Users\KelvinOX25\Documents\GitHub\measDC\55B1_revist 1D chain\img\191111-185418.png'))

# # PID 30,5,1 & htr 10mA for T8 50-350mK
# Tnow_del = []
# Tnow_avg = []

# for Tnow_all in Tnow_alllst:
#     Tnow_all = np.asarray(Tnow_all)
#     Tnow_avg.append(Tnow_all.mean())
#     Tnow_del.append((Tnow_all.max()-Tnow_all.min())/Tnow_all.mean())
# # print(Tnow_avg)

# plt.close('all')
# plt.rc('font', size=10)

# f, ax = plt.subplots(1,2,figsize=(9, 4))
# f.suptitle('PID 30,5,1 & htr 10mA for T8 50-550mK', x = 0.5, y = 0.9)
# f.subplots_adjust(top=0.8)

# ax[0].plot(Tnow_avg,Tnow_del,'.',ls='-')
# ax[0].set_xlabel('T8_avg')
# ax[0].set_ylabel('$\Delta T/T8$')
# ax[0].grid('both')
# # ax[0].ticklabel_format(axis='x', style='sci', scilimits=(0, 4))

# ax[1].plot(Tnow_avg,timer_lst,'.',ls='-')
# ax[1].set_xlabel('T8_avg')
# ax[1].set_ylabel('time spent (sec)')
# ax[1].grid('both')
# ax[1].ticklabel_format(axis='y', style='sci', scilimits=(0, 4))

# %% [markdown]
# ## Observations

# %% [markdown]
# ### Resistive environment effects

# %% [markdown]
# - Comparing N3 and N0 which has similar EJ and EC, but has **different terminating resistor (direct shunt or 100kohm chip resistor) shows different** $R_0$ yet same $I_{SW}$
# - **Preamp power option seems improve** a bit both $R_0$ for from $17k\Omega$ to $10k\Omega$ and $I_{SW}$ from 150pA to 200pA.

# %%
f,ax=plt.subplots()

dataBAT = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N3_IVc-115218.txt')
ax.plot(dataBAT[0]['IS'],dataBAT[0]['V1'], '.', ls='-',label = 'direct shunt, preamp pwr: battery')

dataLIN = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N3_IVc-112927.txt')
ax.plot(dataLIN[0]['IS'],dataLIN[0]['V1'], '.', ls='-',label = 'direct shunt, preamp pwr: line')

dataBAT = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N0_IVc-121229.txt')
ax.plot(dataBAT[0]['IS'],dataBAT[0]['V1'], '.', ls='-',label = '100k$\Omega$, preamp pwr: battery')

dataLIN = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N0_IVc-093912.txt')
ax.plot(dataLIN[0]['IS'],dataLIN[0]['V1'], '.', ls='-',label = '100k$\Omega$, preamp pwr: line')

ax.legend(loc = 4)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ### Device N7 for P(E) theory study

# %%
f,ax=plt.subplots()

dataBAT = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N7_IVc-133848.txt')
ax.plot(dataBAT[0]['IS'],dataBAT[0]['V1'], '.', ls='-',label = 'notch at the return loop')

ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ### Noise study

# %%
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format('70B1N7')
initialise_database()

f,ax=plt.subplots()
for i,v in enumerate([972,974,976,978,980, 986]):
    data = get_data_by_id(v)
    pinlst = ['open door','3ab,4ab', '3ba,4ba', '3ab,4ba', '3ba,4ab', '3ba,4ab_5204']
    Is = data[0][0]['data'][:round(1/2*len(data[0][0]['data']))]
    Vs = data[0][1]['data'][:round(1/2*len(data[0][1]['data']))] - data[0][1]['data'][0]
    
    ax.plot(abs(Is), abs(Vs), '.', ls='-', label = '{}:{}'.format(pinlst[i],v), c = f'C{i}')
    Is = data[0][0]['data'][round(1/2*len(data[0][0]['data'])):]
    Vs = data[0][1]['data'][round(1/2*len(data[0][1]['data'])):] - data[0][1]['data'][0]
    ax.plot(abs(Is), abs(Vs), '', ls='--', c = f'C{i}')

# ax.set_ylim(-2e-6, 10e-6)
# ax.set_xlim(0, 1.2e-9)
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ### Flux trapping concerns
# After GPIB comm error I restarted the magnet, which seems to create trapped flux and some of the deivce was effected (N0)

# %%
SAMPLE = '70B1N5'
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format('70B1N3')   
initialise_database()
f,ax=plt.subplots()

dataLV = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N3_IVc-115218.txt')
ax.plot(dataLV[0]['IS'],dataLV[0]['V1'], '.', ls='-',label = 'meas by LabVIEW')

label = ['b/f restart B_field']

for i,v in enumerate([1]):
    data = get_data_by_id(v)
    Is = data[0][0]['data']
    Vs = data[0][1]['data']
    ax.plot(Is, Vs, '.', ls='-', label = '{}'.format(label[i]))

ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
SAMPLE = '70B1N5'
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format('70B1N5')   
initialise_database()
f,ax=plt.subplots()

dataLV = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N5_IVc-125150.txt')
ax.plot(dataLV[0]['IS'],dataLV[0]['V1'], '.', ls='-',label = 'meas by LabVIEW')

label = ['b/f restart B_field']

for i,v in enumerate([1]):
    data = get_data_by_id(v)
    Is = data[0][0]['data']
    Vs = data[0][1]['data']
    ax.plot(Is, Vs, '.', ls='-', label = '{}'.format(label[i]))

ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format('70B1N0')   
initialise_database()
f,ax=plt.subplots()

dataLV = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N0_IVc-121229.txt')
ax.plot(dataLV[0]['IS'],dataLV[0]['V1'], '.', ls='-',label = 'meas by LabVIEW')

label = ['b/f restart B_field',
         'a/f restart B_field',
         'a/f thermal cycle']

for i,v in enumerate([30,55,56]):
    data = get_data_by_id(v)
    Is = data[0][0]['data']
    Vs = data[0][1]['data']
    ax.plot(Is, Vs, '.', ls='-',label = '{}'.format(label[i]))

ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# BT
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format('70B1N7')   
initialise_database()
f,ax=plt.subplots()

dataLV = filetoDFM(r'\\JOSH-PC\OurData\wsLu\RawData\DC\191104-70N7_IVc-133848.txt')
ax.plot(dataLV[0]['IS'],dataLV[0]['V1'], '.', ls='-',label = 'meas by LabVIEW')

label = ['b/f restart B_field',
         'a/f restart B_field',
         'a/f thermal cycle',
         'meas on Nov 11th']

for i,v in enumerate([105,971,1092,1095]):
    data = get_data_by_id(v)
    Is = data[0][0]['data']
    Vs = data[0][1]['data']
    ax.plot(Is, Vs, '.', ls='-',label = '{}'.format(label[i]))

ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# 290mK
qc.config["core"]["db_location"] = r'\\JOSH-PC\OurData_OneDrive\Experiments_{}.db'.format('70B1N7')   
initialise_database()
f,ax=plt.subplots()
for i in [911,988]:
    data = get_data_by_id(i)
    Is = data[0][0]['data']
    Vs = data[0][1]['data']
    ax.plot(Is, Vs, '.', ls='-')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
