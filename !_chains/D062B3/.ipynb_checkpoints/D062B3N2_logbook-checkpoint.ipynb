# %% [markdown]
# # Environment setup

# %% [markdown]
# ### Library preparation

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import pandas as pd
pd.set_eng_float_format(accuracy=1, use_eng_prefix=True)

import numpy as np

import os

import matplotlib.pyplot as plt

import qcodes as qc
from qcodes.dataset.plotting import plot_by_id, get_data_by_id, plot_dataset
from qcodes.dataset.data_set import load_by_id
from qcodes.instrument.parameter import Parameter


from si_prefix import si_format as SI

# %%
import sys 
sys.path.append('..\..\_jjtools')

# from Exps import *

from JJ_data_processing import read_opj_data, pbi, bpbi, show_df, update_df

from JJformulas import *
from meas_util import *

from JJmeasurement import *
# Out:
# D:\anaconda\lib\site-packages\qcodes\dataset\database.py:13: UserWarning: The module `qcodes.dataset.database` is deprecated.
# Public features are available at the import of `qcodes`.
# Private features are available in `qcodes.dataset.sqlite.*` modules.
#   warnings.warn('The module `qcodes.dataset.database` is deprecated.\n'
# D:\anaconda\lib\site-packages\tqdm\autonotebook\__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Database ini

# %%
SAMPLE = 'D062B3N2'

jj = JJmeas(sample = SAMPLE)

jj.db_connect()

# %% [markdown]
# # Sample discription and runid matrix

# %%
full_table = pd.read_excel("..\chain table.xlsx")

# %%
show_df(full_table, 
         find = SAMPLE
         )
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Ec</th>
#       <th>Ej</th>
#       <th>Iab</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn</th>
#       <th>Rn_tot</th>
#       <th>Ro</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#       <th>wp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>D062B3N2</th>
#       <td>40.0f</td>
#       <td>185.9m</td>
#       <td>136.5m</td>
#       <td>5.7n</td>
#       <td>21.0p</td>
#       <td>20</td>
#       <td>2.0</td>
#       <td>49.6k</td>
#       <td>993000</td>
#       <td>216.0k</td>
#       <td>893.1M</td>
#       <td>4.3M</td>
#       <td>2.5m</td>
#       <td>Fin</td>
#       <td>fabd</td>
#       <td>450.5m</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Import from origin

# %%
Vmock = Parameter(name = 'Voltage', label = 'Voltage', unit = 'V')
Imock = Parameter(name = 'Current', label = 'Current', unit = 'A')

# %%
x, y = read_opj_data(cols = (4,5), preprint = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
runid = jj.mock_meas( x = (Imock, x), y = (Vmock, y) , label = 'IVC full')
# Out:
# Upgrading database; v0 -> v1: : 0it [00:00, ?it/s]
# Upgrading database; v1 -> v2: 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 50.13it/s]
# Upgrading database; v2 -> v3: : 0it [00:00, ?it/s]
# Upgrading database; v3 -> v4: : 0it [00:00, ?it/s]
# Upgrading database; v4 -> v5: 100%|█████████████████████████████████████████████████████| 1/1 [00:00<00:00, 100.27it/s]
# Upgrading database; v5 -> v6: : 0it [00:00, ?it/s]
# Upgrading database; v6 -> v7: 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.54it/s]
# Upgrading database; v7 -> v8: 100%|█████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.57it/s]
# Starting experimental run with id: 1

# %% [markdown]
# # Report

# %% [markdown]
# ## Overview IVC

# %%
pbi(1, interactive = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Vg = 7.5 mV**
#
# **N = 15?**
#
# **Rn_tot = 200k**

# %% [markdown]
# ## IVC fine scan

# %%
pbi(2, interactive = True)
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %% [markdown]
# **Ro_tot = 87 MOhm**
#
# **Isw = 290fA**

# %% [markdown]
# # Datatable update

# %%
ft = pd.read_excel("..\chain table.xlsx")

show_df(ft, 
         find = SAMPLE
         )
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Ec</th>
#       <th>Ej</th>
#       <th>Iab</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn</th>
#       <th>Rn_tot</th>
#       <th>Ro</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#       <th>wp</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
ft = update_df(ft, SAMPLE, 
         
              {'Rn_tot'  : 2.1e6,
               'Ro_tot'  : 87e6,
               'Isw'     : 290e-15,
               'N'       : 20,
               'Ajj'     : 40e-15,
               'status'  : 'measd_lv'
             })

show_df(ft, 
       find = SAMPLE)
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Ec</th>
#       <th>Ej</th>
#       <th>Iab</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn</th>
#       <th>Rn_tot</th>
#       <th>Ro</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#       <th>wp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=./D059BB/D059BBN3_logbook.ipynb>D059BBN3</a></th>
#       <td>40.0f</td>
#       <td>185.9m</td>
#       <td>64.5m</td>
#       <td>2.7n</td>
#       <td>290.0f</td>
#       <td>20.0</td>
#       <td>NaN</td>
#       <td>105.0k</td>
#       <td>2.1M</td>
#       <td>4.4M</td>
#       <td>NaN</td>
#       <td>87.0M</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>measd_lv</td>
#       <td>309.8m</td>
#     </tr>
#   </tbody>
# </table>

# %%
ft.to_excel("..\chain table.xlsx")
