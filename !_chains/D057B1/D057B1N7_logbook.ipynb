# %% [markdown]
# # Environment setup

# %% [markdown]
# ### Library preparation

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import pandas as pd
pd.set_eng_float_format(accuracy=1, use_eng_prefix=True)

import numpy as np

import os

import matplotlib.pyplot as plt

import qcodes as qc
from qcodes.dataset.plotting import plot_by_id, get_data_by_id, plot_dataset
from qcodes.dataset.data_set import load_by_id
from qcodes.instrument.parameter import Parameter


from si_prefix import si_format as SI

# %%
import sys 
sys.path.append('..\..\_jjtools')

# from Exps import *

from JJ_data_processing import read_opj_data, pbi, bpbi, show_df, update_df

from JJformulas import *
from meas_util import *

from JJmeasurement import *
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\dataset\database.py:13: UserWarning: The module `qcodes.dataset.database` is deprecated.
# Public features are available at the import of `qcodes`.
# Private features are available in `qcodes.dataset.sqlite.*` modules.
#   warnings.warn('The module `qcodes.dataset.database` is deprecated.\n'
# C:\ProgramData\Anaconda3\lib\site-packages\tqdm\autonotebook\__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Database ini

# %%
SAMPLE = 'D057B1N7'

jj = JJmeas(sample = SAMPLE)

jj.db_connect()

# %% [markdown]
# # Sample discription and runid matrix

# %% [markdown]
# # Import from origin

# %%
Vmock = Parameter(name = 'Voltage', label = 'Voltage', unit = 'V')
Imock = Parameter(name = 'Current', label = 'Current', unit = 'A')

# %%
x, y = read_opj_data(cols = (4,5), preprint = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
runid = jj.mock_meas( x = (Imock, x), y = (Vmock, y) , label = 'IVC ZF fine')
# Out:
# Upgrading database; v0 -> v1: : 0it [00:00, ?it/s]
# Upgrading database; v1 -> v2: 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 67.74it/s]
# Upgrading database; v2 -> v3: : 0it [00:00, ?it/s]
# Upgrading database; v3 -> v4: : 0it [00:00, ?it/s]
# Upgrading database; v4 -> v5: 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 82.37it/s]
# Upgrading database; v5 -> v6: : 0it [00:00, ?it/s]
# Upgrading database; v6 -> v7: 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 42.30it/s]
# Upgrading database; v7 -> v8: 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 65.98it/s]
# Starting experimental run with id: 1

# %% [markdown]
# # Report

# %% [markdown]
# ## Overview IVC

# %%
plot_by_id(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-08ba77f27854> in <module>
# ----> 1 plot_by_id(2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\dataset\plotting.py in plot_by_id(run_id, axes, colorbars, rescale_axes, auto_color_scale, cutoff_percentile, complex_plot_type, complex_plot_phase, **kwargs)
#     323     """
#     324
# --> 325     dataset = load_by_run_spec(captured_run_id=run_id)
#     326     return plot_dataset(dataset,
#     327                         axes,
#
# C:\ProgramData\Anaconda3\lib\site-packages\qcodes\dataset\data_set.py in load_by_run_spec(captured_run_id, captured_counter, experiment_name, sample_name, sample_id, location, work_station, conn)
#    1206                         "identify a dataset")
#    1207     else:
# -> 1208         raise NameError(f'No run matching the supplied information '
#    1209                         f'found.')
#    1210
#
# NameError: No run matching the supplied information found.

# %%
Vg = np.nan
Rn_tot = np.nan

# %% [markdown]
# ## IVC fine scan

# %%
plot_by_id(1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axes._subplots.AxesSubplot at 0x11d93c1bba8>], [None])

# %%
Ro_tot = 123.5e3
Isw = 700e-12
N  = 30
Vo_tot = 68e-6

# %% [markdown]
# # Datatable update

# %%
ft = pd.read_excel("..\chain table.xlsx", index_col = 0)
show_df(ft, 
         find = SAMPLE
         )
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Ec</th>
#       <th>Ej</th>
#       <th>Iab</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn</th>
#       <th>Rn_tot</th>
#       <th>Ro</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#       <th>wp</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
ft = pd.read_excel("..\chain table.xlsx", index_col = 0)
ft = update_df(ft, SAMPLE, 
         
              {'Rn_tot'  : Rn_tot,
               'Ro_tot'  : Ro_tot,
               'Isw'     : Isw,
               'N'       : N,
               'Vo_tot'  : Vo_tot,
               'Npar'    : 2,
               'dsgn'    : 'Fin',
               'Ajj'     : 40e-15,
               'status'  : 'measd_lv'
             })

show_df(ft, 
       find = SAMPLE)
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Ec</th>
#       <th>Ej</th>
#       <th>Iab</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn</th>
#       <th>Rn_tot</th>
#       <th>Ro</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#       <th>wp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=../D057B1/D057B1N7_logbook.ipynb>D057B1N7</a></th>
#       <td>40.0f</td>
#       <td>185.9m</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>700.0p</td>
#       <td>30.0</td>
#       <td>2.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.1k</td>
#       <td>NaN</td>
#       <td>123.5k</td>
#       <td>68.0u</td>
#       <td>Fin</td>
#       <td>measd_lv</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
ft.to_excel("..\chain table.xlsx")
ft = pd.read_excel("..\chain table.xlsx", index_col = 0)
show_df(ft, 
         find = SAMPLE
         )
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Ec</th>
#       <th>Ej</th>
#       <th>Iab</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn</th>
#       <th>Rn_tot</th>
#       <th>Ro</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#       <th>wp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=../D057B1/D057B1N7_logbook.ipynb>D057B1N7</a></th>
#       <td>40.0f</td>
#       <td>185.9m</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>700.0p</td>
#       <td>30</td>
#       <td>2</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.1k</td>
#       <td>NaN</td>
#       <td>123.5k</td>
#       <td>68.0u</td>
#       <td>Fin</td>
#       <td>measd_lv</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
