# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Environment setup

# %% [markdown]
# ### Library preparation

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys 
sys.path.append('..\..\_jjtools')

# from Exps import *

from JJ_data_processing import read_opj_data, pbi, bpbi, show_df, update_df
from JJ_data_processing import xy_by_id,extract_Isw_R0_by_id


from JJformulas import *
from meas_util import *

from JJmeasurement import *
# Out:
# C:\Users\KelvinOX25\Anaconda3\lib\site-packages\qcodes\dataset\database.py:13: UserWarning: The module `qcodes.dataset.database` is deprecated.
# Public features are available at the import of `qcodes`.
# Private features are available in `qcodes.dataset.sqlite.*` modules.
#   warnings.warn('The module `qcodes.dataset.database` is deprecated.\n'
# C:\Users\KelvinOX25\Anaconda3\lib\site-packages\tqdm\autonotebook.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# # Sample discription and runid matrix

# %%
jj = JJmeas(sample = 'D055B1N6sv1')

jj.db_connect()

# %% [markdown]
# pins 11ab 12ab
# gate 2b

# %% [markdown]
# # Meas

# %%
jj.bpbi(range(146, 241+1))
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %% [markdown]
# ## IVC overview

# %%
jj.pbi(1, interactive = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Rn_tot = 7.9k
# Vg = .4
# N = 1

# %%
7/(7.9)
# Out:
# 0.8860759493670886

# %% [markdown]
# Ej = 0.88 K

# %% [markdown]
# ## Fine scan

# %%
jj.pbi(2, ls = '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# B = 100

# %%
jj.pbi(4, ls = '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# B = 180

# %%
jj.pbi(5, ls = '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
jj.pbi(8, ls = '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## afret few days

# %%
jj.pbi(11)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Bscan

# %%
jj.bpbi(range(12, 28+1))
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
jj.pbi(31, ls = '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## fine scan B = -3.5m

# %%
jj.pbi(33)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
jj.pbi(35)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Connect Vgate

# %%
jj.pbi(38)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
jj.bpbi(range(146, 241+1))
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %% [markdown]
# ## New heading

# %%
jj.bpbi([35, 41, 42, 43, 44],marker = '.',
        labels = ['wo Vg', 'w\ Vg (2b)', 'Vg plugged diff site (1a)',
                  'Vg plugged nowhere', 'Vg plugged nowhere (1b)', 
                  'Vg plugged diff site (1a)', 'w\ Vg (2b)', 'w\ Vg (2b)',
                  'Vg plugged diff site (1a)'])
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">

# %%
jj.bpbi([ 44, 45, 46, 47, 48],marker = '.',
        labels = [ 'Vg plugged nowhere (1b)', 
                  'Vg plugged diff site (1a)', 'w\ Vg (2b)', 'w\ Vg (2b)',
                  'Vg plugged diff site (1a)'])
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# something just happend, and Isw is greater now. check b=0

# %%
jj.pbi(51)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
jj.bpbi([2, 51], labels = ['before', 'after'])
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">

# %%
V = 1

# %%
jj.bpbi([51, 52, 53, 55], labels = ['V = 0', 'V = 1', 'V = -1', 'V = 2'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
jj.bpbi(range(58+1, 98+1))
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
jj.pbi(58)
# Out:
# C:\Users\KelvinOX25\Anaconda3\lib\site-packages\qcodes\dataset\plotting.py:196: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 1, **subplots_kwargs)
# <img src="data:image/png;base64,..." width="640">

# %%
jj.pbi(100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# wow, it looks like Vg dependence! Note that not Vg is connected to another site capacitor (1a), double check tomorrow
#
# is there any periodicity? or it's just heating??

# %%
jj.bpbi(range(104, 109+1))
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %% [markdown]
# no jumps - increase the ampl?
#
# and first icv is wierd, getting better after - heating??

# %%
jj.bpbi(range(110, 124+1))
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %% [markdown]
# ??
#
# v = 0.5

# %%
jj.bpbi([125, 126, 127, 130, 131],
        labels = ['v=0.5', 'v=0', 'v=1.5', 'v=1.5', 'v=3'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# overheating in manual regime. why i cannot see it in Vscan

# %%
jj.bpbi(range(133, 136+1),
        labels = ['v=0.5', 'v=1', 'v=1.5', 'v=2', 'v=2.5'])
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ok, now overheating is obvious. but before i saw just supression of Isw??
#
# repeat v = b = 0

# %%
jj.pbi(140)
# Out:
# C:\Users\KelvinOX25\Anaconda3\lib\site-packages\qcodes\dataset\plotting.py:196: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 1, **subplots_kwargs)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Bscan again (greater Isw)

# %% [markdown]
# ### jj.bpbi(range(142, 142+1))

# %%
jj.bpbi(range(146, 241+1))
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
jj.pbi(247, ls = '-')
# Out:
# C:\Users\KelvinOX25\Anaconda3\lib\site-packages\qcodes\dataset\plotting.py:196: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 1, **subplots_kwargs)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# compare with old

# %%
jj.bpbi([247, 31], labels = ['new', 'old'])
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# try again for negative B

# %%
jj.bpbi(range(248, 258+1))
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
jj.bpbi([247, 31, 259], ls = '-', 
        labels = ['new', 'old', 'new neg only'])
# Out:
# ..\..\_jjtools\JJ_data_processing.py:165: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# remeas B = 0 to make sure Isw is recovered?

# %%
jj.pbi(260)
# Out:
# C:\Users\KelvinOX25\Anaconda3\lib\site-packages\qcodes\dataset\plotting.py:196: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 1, **subplots_kwargs)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# it's fine, go to 4s

# %% [markdown]
# # Results

# %% [markdown]
# ## to do
