# %% [markdown]
# # Environment setup

# %% [markdown]
# ### Library preparation

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import pandas as pd
pd.set_eng_float_format(accuracy=1, use_eng_prefix=True)

import numpy as np

import os

import matplotlib.pyplot as plt

import qcodes as qc
from qcodes.dataset.plotting import plot_by_id, get_data_by_id, plot_dataset
from qcodes.dataset.data_set import load_by_id
from qcodes.instrument.parameter import Parameter


from si_prefix import si_format as SI

# %%
import sys 
sys.path.append('..\..\_jjtools')

# from Exps import *

from JJ_data_processing import read_opj_data, pbi, bpbi, show_df, update_df

from JJformulas import *
from meas_util import *

from JJmeasurement import *

# %% [markdown]
# ### Database ini

# %%
SAMPLE = 'D053N2'

jj = JJmeas(sample = SAMPLE)

jj.db_connect()

# %% [markdown]
# # Sample discription and runid matrix

# %%
show_df(full_table)
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn_tot</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=../D053/D053N2_logbook.ipynb>D053N2</a></th>
#       <td>40.0f</td>
#       <td>90.0n</td>
#       <td>20</td>
#       <td>2</td>
#       <td>9300</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.6m</td>
#       <td>Fin</td>
#       <td>measd</td>
#     </tr>
#     <tr>
#       <th>D055B1N9</th>
#       <td>40.0f</td>
#       <td>153.0p</td>
#       <td>20</td>
#       <td>2</td>
#       <td>115000</td>
#       <td>666.8M</td>
#       <td>1.0M</td>
#       <td>1.7m</td>
#       <td>Fin</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D059B0N1</th>
#       <td>40.0f</td>
#       <td>3.9n</td>
#       <td>2</td>
#       <td>2</td>
#       <td>8750</td>
#       <td>1.6G</td>
#       <td>1.3k</td>
#       <td>217.8u</td>
#       <td>Fin</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D059B6N3</th>
#       <td>40.0f</td>
#       <td>2.0n</td>
#       <td>20</td>
#       <td>2</td>
#       <td>84300</td>
#       <td>25.9M</td>
#       <td>78.8k</td>
#       <td>1.9m</td>
#       <td>Fin</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D059BBN1</th>
#       <td>4.0p</td>
#       <td>600.0f</td>
#       <td>30</td>
#       <td>2</td>
#       <td>745000</td>
#       <td>NaN</td>
#       <td>240.0M</td>
#       <td>0.0y</td>
#       <td>x_L</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D059BBN2</th>
#       <td>40.0f</td>
#       <td>320.0f</td>
#       <td>20</td>
#       <td>2</td>
#       <td>1750000</td>
#       <td>903.2M</td>
#       <td>236.7M</td>
#       <td>1.4m</td>
#       <td>Fin</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D059BBN2_n</th>
#       <td>22.5f</td>
#       <td>NaN</td>
#       <td>30</td>
#       <td>2</td>
#       <td>1950000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0y</td>
#       <td>x_L</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D059BBN8</th>
#       <td>4.0p</td>
#       <td>750.0f</td>
#       <td>30</td>
#       <td>2</td>
#       <td>1780000</td>
#       <td>NaN</td>
#       <td>50.0M</td>
#       <td>0.0y</td>
#       <td>x_L</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D060B2N2</th>
#       <td>40.0f</td>
#       <td>2.7p</td>
#       <td>4</td>
#       <td>2</td>
#       <td>119000</td>
#       <td>920.9M</td>
#       <td>29.1M</td>
#       <td>318.6u</td>
#       <td>Fin</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D060B2N6</th>
#       <td>40.0f</td>
#       <td>1.2p</td>
#       <td>20</td>
#       <td>2</td>
#       <td>664000</td>
#       <td>958.7M</td>
#       <td>22.9M</td>
#       <td>3.3m</td>
#       <td>Fin</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D062B3N2</th>
#       <td>40.0f</td>
#       <td>21.0p</td>
#       <td>20</td>
#       <td>2</td>
#       <td>993000</td>
#       <td>893.1M</td>
#       <td>4.3M</td>
#       <td>2.5m</td>
#       <td>Fin</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D063BAN6_a</th>
#       <td>4.0p</td>
#       <td>22.0p</td>
#       <td>30</td>
#       <td>2</td>
#       <td>585000</td>
#       <td>13.8M</td>
#       <td>265.0k</td>
#       <td>3.1m</td>
#       <td>x_s</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D063BAN6_b</th>
#       <td>40.0f</td>
#       <td>20.0p</td>
#       <td>30</td>
#       <td>2</td>
#       <td>594000</td>
#       <td>935.0M</td>
#       <td>7.7M</td>
#       <td>5.0m</td>
#       <td>x_s</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th>D066B8N5_b</th>
#       <td>40.0f</td>
#       <td>5.4n</td>
#       <td>30</td>
#       <td>2</td>
#       <td>66100</td>
#       <td>146.3M</td>
#       <td>851.0</td>
#       <td>1.7m</td>
#       <td>x_s</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th><a target="_blank" href=../D070B1/D070B1N0_logbook.ipynb>D070B1N0</a></th>
#       <td>4.0p</td>
#       <td>160.0p</td>
#       <td>15</td>
#       <td>2</td>
#       <td>168000</td>
#       <td>NaN</td>
#       <td>23.7k</td>
#       <td>NaN</td>
#       <td>x_L</td>
#       <td>measd</td>
#     </tr>
#     <tr>
#       <th><a target="_blank" href=../D074/D074N4_logbook.ipynb>D074N4</a></th>
#       <td>2.2p</td>
#       <td>9.0n</td>
#       <td>9</td>
#       <td>2</td>
#       <td>13500</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>2.0m</td>
#       <td>x_L</td>
#       <td>measd</td>
#     </tr>
#     <tr>
#       <th><a target="_blank" href=../D078/D078N0_logbook.ipynb>D078N0</a></th>
#       <td>4.0p</td>
#       <td>37.1p</td>
#       <td>15</td>
#       <td>2</td>
#       <td>254000</td>
#       <td>NaN</td>
#       <td>10.0k</td>
#       <td>1.9m</td>
#       <td>x_L</td>
#       <td>measd</td>
#     </tr>
#     <tr>
#       <th><a target="_blank" href=../D078/D078N5_logbook.ipynb>D078N5</a></th>
#       <td>4.0p</td>
#       <td>800.0p</td>
#       <td>1</td>
#       <td>2</td>
#       <td>16700</td>
#       <td>NaN</td>
#       <td>100.0k</td>
#       <td>96.8u</td>
#       <td>x_L</td>
#       <td>measd</td>
#     </tr>
#     <tr>
#       <th>D079N5</th>
#       <td>3.7p</td>
#       <td>5.6n</td>
#       <td>15</td>
#       <td>2</td>
#       <td>23300</td>
#       <td>NaN</td>
#       <td>-307.0</td>
#       <td>2.0m</td>
#       <td>x_L</td>
#       <td>fabd</td>
#     </tr>
#     <tr>
#       <th><a target="_blank" href=../D079/D079N6_logbook.ipynb>D079N6</a></th>
#       <td>3.7p</td>
#       <td>137.0n</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1450</td>
#       <td>NaN</td>
#       <td>2.2</td>
#       <td>164.5u</td>
#       <td>x_L</td>
#       <td>measd</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_df(full_table, 
         find = SAMPLE
         )
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn_tot</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=../D053/D053N2_logbook.ipynb>D053N2</a></th>
#       <td>40.0f</td>
#       <td>90.0n</td>
#       <td>20</td>
#       <td>2</td>
#       <td>9300</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.6m</td>
#       <td>Fin</td>
#       <td>measd</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Import from origin

# %%
Vmock = Parameter(name = 'Voltage', label = 'Voltage', unit = 'V')
Imock = Parameter(name = 'Current', label = 'Current', unit = 'A')

# %%
x, y = read_opj_data(cols = (4,5), preprint = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
runid = jj.mock_meas( x = (Imock, x), y = (Vmock, y) , label = 'IVC fine')
# Out:
# Starting experimental run with id: 2

# %% [markdown]
# # Report

# %% [markdown]
# ## Overview IVC

# %%
pbi(2, interactive = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Vg = 6.5mV**
#
# **N = 30**
#
# **Rn_tot = 8.9k**

# %%
8/.4
# Out:
# 20.0

# %%
Vg = 6.5e-3
Rn_tot = 8.9e3

# %% [markdown]
# ## IVC fine scan

# %%
pbi(2, interactive = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Ro_tot = 734 Ohm**
#
# **Isw = 90.6nA**

# %%
Ro_tot = 734
Isw = 90.6e-9
N  = 30
Vo_tot = 304e-6

# %% [markdown]
# # Datatable update

# %%
ft = pd.read_excel("..\chain table.xlsx", index_col = 0)

show_df(ft, 
         find = SAMPLE
         )
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn_tot</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=../D053/D053N2_logbook.ipynb>D053N2</a></th>
#       <td>40.0f</td>
#       <td>90.0n</td>
#       <td>20</td>
#       <td>2</td>
#       <td>9300</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.6m</td>
#       <td>Fin</td>
#       <td>measd</td>
#     </tr>
#   </tbody>
# </table>

# %%
ft = update_df(ft, SAMPLE, 
         
              {'Rn_tot'  : Rn_tot,
               'Ro_tot'  : Ro_tot,
               'Isw'     : Isw,
               'N'       : N,
               'Ajj'     : 40e-15,
               'status'  : 'measd_lv'
             })

show_df(ft, 
       find = SAMPLE)
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Ec</th>
#       <th>Ej</th>
#       <th>Iab</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn</th>
#       <th>Rn_tot</th>
#       <th>Ro</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#       <th>wp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=../D053/D053N2_logbook.ipynb>D053N2</a></th>
#       <td>40.0f</td>
#       <td>185.9m</td>
#       <td>22.8</td>
#       <td>958.2n</td>
#       <td>90.6n</td>
#       <td>30</td>
#       <td>2</td>
#       <td>296.7</td>
#       <td>8.9k</td>
#       <td>24.5</td>
#       <td>NaN</td>
#       <td>734.0</td>
#       <td>1.6m</td>
#       <td>Fin</td>
#       <td>measd_lv</td>
#       <td>5.8</td>
#     </tr>
#   </tbody>
# </table>

# %%
ft.to_excel("..\chain table.xlsx")

# %%
ft = pd.read_excel("..\chain table.xlsx", index_col = 0)

show_df(ft, 
         find = SAMPLE
         )
# Out:
# <table border="1" class="dataframe table table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ajj</th>
#       <th>Ec</th>
#       <th>Ej</th>
#       <th>Iab</th>
#       <th>Isw</th>
#       <th>N</th>
#       <th>Npar</th>
#       <th>Rn</th>
#       <th>Rn_tot</th>
#       <th>Ro</th>
#       <th>RoFF</th>
#       <th>Ro_tot</th>
#       <th>Vo_tot</th>
#       <th>dsgn</th>
#       <th>status</th>
#       <th>wp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=../D053/D053N2_logbook.ipynb>D053N2</a></th>
#       <td>40.0f</td>
#       <td>185.9m</td>
#       <td>22.8</td>
#       <td>958.2n</td>
#       <td>90.6n</td>
#       <td>30</td>
#       <td>2</td>
#       <td>296.7</td>
#       <td>8900</td>
#       <td>24.5</td>
#       <td>NaN</td>
#       <td>734.0</td>
#       <td>1.6m</td>
#       <td>Fin</td>
#       <td>measd_lv</td>
#       <td>5.8</td>
#     </tr>
#   </tbody>
# </table>
